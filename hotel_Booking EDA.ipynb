# %% [markdown]
# ## 1. Dataset and its context
# This dataset comprises booking details for urban and vacation hotels, encompassing information like reservation timestamp, duration of stay, count of adult guests, children and/or infants, and the availability of parking spaces.

# %% [markdown]
# ## 2. Import packages & read data.
# We will import these packages and libraries to analyze and visualize data:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import datetime

# %%
df=pd.read_csv(r"E:\Downloads\hotel_bookings.csv.zip")

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
len(df.index)
# Out:
# 119390

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ## 3. Data Preparation
# Handle missing values

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
for i in df.columns:
  if df[i].isna().sum() != 0:
    print('null values in', i, 'column :', df[i].isna().sum() )
# Out:
# null values in children column : 4
# null values in country column : 488
# null values in agent column : 16340
# null values in company column : 112593

# %%
df = df.drop(columns = 'company')
df = df.dropna(subset = ['children'])
df['country'].fillna(df['country'].mode()[0], inplace = True)
df['agent'].fillna(0, inplace = True)

# %% [markdown]
# ## Convert columns values
# We can see some confusing values like TA/TO and BB, FB, HB, we will replaced it so it will be easier for us to conduct further analysis.

# %%
df['distribution_channel'].replace("TA/TO", "Undefined", inplace = True)
df['meal'].replace(['Undefined', 'BB', 'FB', 'HB', 'SC'], 
                   [ 'No Meal', 'Breakfast', 'Full Board', 'Hald Board', 'No Meal'],
                   inplace = True)

# %% [markdown]
# ## Changing datatypes
# We spot some columns still in string types, let s modify it:

# %%
df['children'].astype(int)
df['agent'].astype(int)
pd.to_datetime(df['reservation_status_date'])
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 119386, dtype: datetime64[ns]

# %% [markdown]
# ## Handle duplicates
# We run below code to figure out the number of duplicated rows. We will remove them because it is very unlikely to to have 2 similar rows. It means we assume that there no 2 booking with similar number of people, date, channel, agent, number of requirements, and booking history.
#
# We can just drop those duplicated columns:

# %%
df.duplicated().sum()
# Out:
# 32020

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# Create new columns by combining other columns

# %%
df['total_night'] = df['stays_in_weekend_nights'] + df['stays_in_weekend_nights']

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87366.000000  87366.000000       87366.000000
# mean       0.274935     79.915207        2016.210345
# std        0.446484     86.056865           0.686082
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87366.000000               87366.000000
# mean                  26.839285                  15.815786
# std                   13.673468                   8.834781
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %%
#create total night column
df['total_night'] = df['stays_in_weekend_nights'] + df['stays_in_weekend_nights']

#convert month name to number then create new arrival date column by combining year month date
df['arrival_date_month'] = pd.to_datetime(df['arrival_date_month'] , format='%B').dt.month
df['arrival_date'] = pd.to_datetime(dict(year=df.arrival_date_year, month=df.arrival_date_month, day=df.arrival_date_day_of_month))

# %% [markdown]
# ## Drop unnecessary columns
# Drop unnecessary columns as we already used them to create new columns

# %%
columns_to_drop = ['stays_in_weekend_nights','stays_in_week_nights', 'booking_changes','deposit_type','adr','arrival_date_year','arrival_date_month','arrival_date_day_of_month','arrival_date_week_number']
df.drop(columns = columns_to_drop, inplace = True)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  adults  children  babies       meal  \
# 0  Resort Hotel            0        342       2       0.0       0  Breakfast
# 1  Resort Hotel            0        737       2       0.0       0  Breakfast
# 2  Resort Hotel            0          7       1       0.0       0  Breakfast
# 3  Resort Hotel            0         13       1       0.0       0  Breakfast
# 4  Resort Hotel            0         14       2       0.0       0  Breakfast
#
#   country market_segment distribution_channel  ...  reserved_room_type  \
# 0     PRT         Direct               Direct  ...                   C
# 1     PRT         Direct               Direct  ...                   C
# 2     GBR         Direct               Direct  ...                   A
# 3     GBR      Corporate            Corporate  ...                   A
# 4     GBR      Online TA            Undefined  ...                   A
#
#    assigned_room_type  agent days_in_waiting_list customer_type  \
# ...

# %%
df.to_csv('result.csv', index=False)

# %%
corr_matrix = round(df.corr(),3)
corr_matrix
# Out:
#                                 is_canceled  lead_time  adults  children  \
# is_canceled                           1.000      0.185   0.082     0.067
# lead_time                             0.185      1.000   0.140     0.029
# adults                                0.082      0.140   1.000     0.024
# children                              0.067      0.029   0.024     1.000
# babies                               -0.021     -0.004   0.017     0.017
# is_repeated_guest                    -0.090     -0.147  -0.172    -0.046
# previous_cancellations                0.051      0.005  -0.042    -0.019
# previous_bookings_not_canceled       -0.052     -0.079  -0.121    -0.029
# agent                                -0.001      0.080   0.030     0.042
# days_in_waiting_list                  0.004      0.132  -0.016    -0.020
# required_car_parking_spaces          -0.184     -0.087   0.008     0.036
# total_of_special_requests            -0.121      0.034   0.113     0.045
# ...

# %% [markdown]
# ## Correlation heatmap
# Type of plot that visualize the strength of relationships between numerical variables. Here how I build it:

# %%
plt.rcParams['figure.figsize'] =(12, 6)
sns.heatmap(df.corr(), annot=True, cmap='Reds', linewidths=5)
plt.suptitle('Correlation Between Variables', fontweight='heavy', 
             x=0.03, y=0.98, ha = "left", fontsize='18', fontfamily='sans-serif', 
             color= "black")
# Out:
# Text(0.03, 0.98, 'Correlation Between Variables')

# %% [markdown]
# ## 5. Exploratory Data Analysis
# ## Understand the context
# In order to conduct EDA, data analyst will need to be able to come up with right questions to start the process. These questions will help to keep our mind on track and set our expectation during the process.
#
# Keep in mind that we will need some constrains for our questions because there will be thousands of approach that we can use to come up with the questions. Some constraints can be project goals, business objectives, company values, and client expectations.
